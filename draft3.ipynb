# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
#!pip install Pillow
from PIL import Image
#!pip install pyshp
import shapefile

# %%
#Cargamos todas las entidades para ver el mapa de México detallado
#ruta_mexico = r'C:\Users\User\Maestria\Tesis\889463770541_s'

fig00a = gpd.read_file(r'C:\Users\User\Maestria\Tesis\889463770541_s\mg2022_integrado\00a.shp')
fig00ent = gpd.read_file(r'C:\Users\User\Maestria\Tesis\889463770541_s\mg2022_integrado\00ent.shp')
fig00l = gpd.read_file(r'C:\Users\User\Maestria\Tesis\889463770541_s\mg2022_integrado\00l.shp')
fig001pr = gpd.read_file(r'C:\Users\User\Maestria\Tesis\889463770541_s\mg2022_integrado\00lpr.shp')
fig00mun = gpd.read_file(r'C:\Users\User\Maestria\Tesis\889463770541_s\mg2022_integrado\00mun.shp')

# Crear una figura y un conjunto de ejes
fig, ax = plt.subplots(figsize=(10, 10))

# Dibujar el mapa de fig00ent y fig00l
fig00ent.plot(ax=ax, color='pink')
fig00l.plot(ax=ax, color='green')

# Añadir los puntos de gdf_mayoristas
gdf_mayoristas.plot(ax=ax, color='blue')

# Establecer los límites de la figura
ax.set_xlim(x_min , x_max)
ax.set_ylim(y_min , y_max)

# Ajustar la relación de aspecto de los ejes
ax.set_aspect('equal')

plt.show()

# %%
type(fig00ent)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
fig00a #Podemos ver la diferencia de escala
# Out:
#               CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  AMBITO  \
# 0      010010001216A      01     001    0001     216A  Urbana
# 1      0100100012649      01     001    0001     2649  Urbana
# 2      010010001383A      01     001    0001     383A  Urbana
# 3      010010001287A      01     001    0001     287A  Urbana
# 4      010010001084A      01     001    0001     084A  Urbana
# ...              ...     ...     ...     ...      ...     ...
# 81810      320560025      32     056     NaN     0025   Rural
# 81811      320570145      32     057     NaN     0145   Rural
# 81812      32057015A      32     057     NaN     015A   Rural
# 81813      320580049      32     058     NaN     0049   Rural
# 81814      320580053      32     058     NaN     0053   Rural
#
#                                                 geometry
# 0      POLYGON ((2472175.611 1095222.905, 2472149.898...
# 1      POLYGON ((2474436.992 1094330.964, 2474423.306...
# 2      POLYGON ((2472973.672 1091954.736, 2472991.031...
# 3      POLYGON ((2468473.209 1093564.706, 2468482.070...
# 4      POLYGON ((2469318.936 1094912.739, 2469386.691...
# ...                                                  ...
# 81810  POLYGON ((2433798.367 1199391.586, 2433794.383...
# 81811  POLYGON ((2461787.730 1191158.856, 2461864.269...
# 81812  POLYGON ((2471607.888 1193484.734, 2471555.372...
# 81813  POLYGON ((2357518.262 1062926.008, 2357595.492...
# 81814  POLYGON ((2369896.055 1056491.160, 2370237.776...
#
# [81815 rows x 7 columns]

# %%
#Tengo que buscar la forma de estalar los puntos al mapa y tomarlos como limites

# %%
#Cargar base de datos, descargada de INEGI
df = pd.read_csv('denue_inegi_43_.csv', encoding='ISO-8859-1')
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15052\3448686326.py:2: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('denue_inegi_43_.csv', encoding='ISO-8859-1')
#              id                          clee  \
# 0       7702819  01001434225001101000000000S1
# 1       6282298  01005431110000031001004190S9
# 2       6281310  01005431191000017000002859S8
# 3       6281199  01001431191000106000002859S8
# 4       6281969  01001431110000121001004190S7
# ...         ...                           ...
# 168035  6417662  32017431160000033001003869S8
# 168036  9041093  32017434222000101000000000M8
# 168037  6417535  32017431160000011000004198S4
# 168038  9252599  32056431160000044000002515S3
# 168039  7941345  32010434112000732000000000M8
#
#                                        nom_estab  \
# 0           2 CONEXION DE SERVICIOS INFORMATICOS
# 1       2227 ORGANIZACIÓN SAHUAYO AGUASCALIENTES
# 2                               2251 AGUAS NORTE
# 3                                 2252 AGUAS SUR
# 4                            2273 AGUASCALIENTES
# ...                                          ...
# 168035                                    YAKULT
# 168036                            ZAC PERFORATIC
# 168037                                 ZACATECAS
# 168038                                 ZACATECAS
# 168039                                    ZENDEL
#
#                                                raz_social  codigo_act  \
# 0                                                     NaN      434225
# 1                              IMPULSORA SAHUAYO SA DE CV      431110
# 2                                          BIMBO SA DE CV      431191
# 3                                          BIMBO SA DE CV      431191
# 4                              IMPULSORA SAHUAYO SA DE CV      431110
# ...                                                   ...         ...
# 168035                                    YAKULT SA DE CV      431160
# 168036                            ZAC PERFORATIC SA DE CV      434222
# 168037                                  DANONE DE MEXICO       431160
# 168038                             MARCAS NESTLE SA DE CV      431160
# 168039  ASOCIACION DE PRODURCTORES DE FRIJOL DEL MINER...      434112
#
#                                                nombre_act             per_ocu  \
# 0       Comercio al por mayor de equipo y material elé...      0 a 5 personas
# 1                      Comercio al por mayor de abarrotes  101 a 250 personas
# 2                 Comercio al por mayor de pan y pasteles  251 y más personas
# 3                 Comercio al por mayor de pan y pasteles  101 a 250 personas
# 4                      Comercio al por mayor de abarrotes  101 a 250 personas
# ...                                                   ...                 ...
# 168035  Comercio al por mayor de leche y otros product...    31 a 50 personas
# 168036  Comercio al por mayor de productos químicos pa...      0 a 5 personas
# 168037  Comercio al por mayor de leche y otros product...    31 a 50 personas
# 168038  Comercio al por mayor de leche y otros product...   51 a 100 personas
# 168039  Comercio al por mayor de medicamentos veterina...     6 a 10 personas
#
#         tipo_vial            nom_vial          tipo_v_e_1  ...  \
# 0           CALLE           5 DE MAYO               CALLE  ...
# 1        CIRCUITO  AGUASCALIENTES SUR            CIRCUITO  ...
# 2       CARRETERA        PANAMERICANA  OTRO (ESPECIFIQUE)  ...
# 3       CARRETERA    PANAMERICANA SUR               CALLE  ...
# 4           CALLE                SOYA             AVENIDA  ...
# ...           ...                 ...                 ...  ...
# 168035      CALLE       PABLO PICASSO               CALLE  ...
# 168036    AVENIDA           5 DE MAYO             PRIVADA  ...
# 168037      CALLE             CANTERA               CALLE  ...
# 168038    AVENIDA     Tránsito Pesado               CALLE  ...
# 168039      CALLE       FRESNILLO SUR               CALLE  ...
#
#                                                 localidad  ageb manzana  \
# 0                                          Aguascalientes  0638      14
# 1       Parque Industrial del Valle de Aguascalientes ...  0035       3
# 2                                      Coral [Ex-Viñedos]  0035     800
# 3                                          Aguascalientes  1477      25
# 4                                          Aguascalientes  1975      16
# ...                                                   ...   ...     ...
# 168035                                          Guadalupe  0224      16
# 168036                                          Guadalupe  0667      16
# 168037                                          Guadalupe  0239       4
# 168038                                          Zacatecas  1220       1
# 168039                                          Fresnillo  279A      16
#
#             telefono                        correoelec                 www  \
# 0                NaN           SERVICIOS@2CONEXION.COM   WWW.2CONEXION.COM
# 1                NaN                               NaN  WWW.SAHUAYO.COM.MX
# 2                NaN                               NaN    WWW.BIMBO.COM.MX
# 3                NaN                               NaN    WWW.BIMBO.COM.MX
# 4                NaN                               NaN  WWW.SAHUAYO.COM.MX
# ...              ...                               ...                 ...
# 168035           NaN                               NaN   WWW.YAKULT.COM.MX
# 168036           NaN                               NaN                 NaN
# 168037           NaN                               NaN                 NaN
# 168038           NaN  RAYMUNDO.RODRIGUEZ@MX.NESTLE.COM                 NaN
# 168039  4939597891.0                               NaN                 NaN
#
#        tipoUniEco    latitud    longitud  fecha_alta
# 0            Fijo  21.882623 -102.297289     2019-11
# 1            Fijo  21.963603 -102.279136     2010-07
# 2            Fijo  21.954421 -102.291284     2010-07
# 3            Fijo  21.840966 -102.280381     2010-07
# 4            Fijo  21.910507 -102.296908     2010-07
# ...           ...        ...         ...         ...
# 168035       Fijo  22.751397 -102.501325     2010-07
# 168036       Fijo  22.755366 -102.524299     2019-11
# 168037       Fijo  22.740396 -102.503876     2010-07
# 168038       Fijo  22.754184 -102.575988     2020-04
# 168039       Fijo  23.200119 -102.851135     2019-11
#
# [168040 rows x 42 columns]

# %%
#¿Cuantas abarroteras mayoristas existen?
len(df.id)
# Out:
# 168040

# %%
#Agregamos una columna de clasificacion para saber que es mayorista
May = []
for i in range(len(df)):
    may = 'Mayorista'
    May.append(may)
df['Clasificación'] = May
df
# Out:
#              id                          clee  \
# 0       7702819  01001434225001101000000000S1
# 1       6282298  01005431110000031001004190S9
# 2       6281310  01005431191000017000002859S8
# 3       6281199  01001431191000106000002859S8
# 4       6281969  01001431110000121001004190S7
# ...         ...                           ...
# 168035  6417662  32017431160000033001003869S8
# 168036  9041093  32017434222000101000000000M8
# 168037  6417535  32017431160000011000004198S4
# 168038  9252599  32056431160000044000002515S3
# 168039  7941345  32010434112000732000000000M8
#
#                                        nom_estab  \
# 0           2 CONEXION DE SERVICIOS INFORMATICOS
# 1       2227 ORGANIZACIÓN SAHUAYO AGUASCALIENTES
# 2                               2251 AGUAS NORTE
# 3                                 2252 AGUAS SUR
# 4                            2273 AGUASCALIENTES
# ...                                          ...
# 168035                                    YAKULT
# 168036                            ZAC PERFORATIC
# 168037                                 ZACATECAS
# 168038                                 ZACATECAS
# 168039                                    ZENDEL
#
#                                                raz_social  codigo_act  \
# 0                                                     NaN      434225
# 1                              IMPULSORA SAHUAYO SA DE CV      431110
# 2                                          BIMBO SA DE CV      431191
# 3                                          BIMBO SA DE CV      431191
# 4                              IMPULSORA SAHUAYO SA DE CV      431110
# ...                                                   ...         ...
# 168035                                    YAKULT SA DE CV      431160
# 168036                            ZAC PERFORATIC SA DE CV      434222
# 168037                                  DANONE DE MEXICO       431160
# 168038                             MARCAS NESTLE SA DE CV      431160
# 168039  ASOCIACION DE PRODURCTORES DE FRIJOL DEL MINER...      434112
#
#                                                nombre_act             per_ocu  \
# 0       Comercio al por mayor de equipo y material elé...      0 a 5 personas
# 1                      Comercio al por mayor de abarrotes  101 a 250 personas
# 2                 Comercio al por mayor de pan y pasteles  251 y más personas
# 3                 Comercio al por mayor de pan y pasteles  101 a 250 personas
# 4                      Comercio al por mayor de abarrotes  101 a 250 personas
# ...                                                   ...                 ...
# 168035  Comercio al por mayor de leche y otros product...    31 a 50 personas
# 168036  Comercio al por mayor de productos químicos pa...      0 a 5 personas
# 168037  Comercio al por mayor de leche y otros product...    31 a 50 personas
# 168038  Comercio al por mayor de leche y otros product...   51 a 100 personas
# 168039  Comercio al por mayor de medicamentos veterina...     6 a 10 personas
#
#         tipo_vial            nom_vial          tipo_v_e_1  ...  ageb manzana  \
# 0           CALLE           5 DE MAYO               CALLE  ...  0638      14
# 1        CIRCUITO  AGUASCALIENTES SUR            CIRCUITO  ...  0035       3
# 2       CARRETERA        PANAMERICANA  OTRO (ESPECIFIQUE)  ...  0035     800
# 3       CARRETERA    PANAMERICANA SUR               CALLE  ...  1477      25
# 4           CALLE                SOYA             AVENIDA  ...  1975      16
# ...           ...                 ...                 ...  ...   ...     ...
# 168035      CALLE       PABLO PICASSO               CALLE  ...  0224      16
# 168036    AVENIDA           5 DE MAYO             PRIVADA  ...  0667      16
# 168037      CALLE             CANTERA               CALLE  ...  0239       4
# 168038    AVENIDA     Tránsito Pesado               CALLE  ...  1220       1
# 168039      CALLE       FRESNILLO SUR               CALLE  ...  279A      16
#
#             telefono                        correoelec                 www  \
# 0                NaN           SERVICIOS@2CONEXION.COM   WWW.2CONEXION.COM
# 1                NaN                               NaN  WWW.SAHUAYO.COM.MX
# 2                NaN                               NaN    WWW.BIMBO.COM.MX
# 3                NaN                               NaN    WWW.BIMBO.COM.MX
# 4                NaN                               NaN  WWW.SAHUAYO.COM.MX
# ...              ...                               ...                 ...
# 168035           NaN                               NaN   WWW.YAKULT.COM.MX
# 168036           NaN                               NaN                 NaN
# 168037           NaN                               NaN                 NaN
# 168038           NaN  RAYMUNDO.RODRIGUEZ@MX.NESTLE.COM                 NaN
# 168039  4939597891.0                               NaN                 NaN
#
#         tipoUniEco    latitud    longitud fecha_alta  Clasificación
# 0             Fijo  21.882623 -102.297289    2019-11      Mayorista
# 1             Fijo  21.963603 -102.279136    2010-07      Mayorista
# 2             Fijo  21.954421 -102.291284    2010-07      Mayorista
# 3             Fijo  21.840966 -102.280381    2010-07      Mayorista
# 4             Fijo  21.910507 -102.296908    2010-07      Mayorista
# ...            ...        ...         ...        ...            ...
# 168035        Fijo  22.751397 -102.501325    2010-07      Mayorista
# 168036        Fijo  22.755366 -102.524299    2019-11      Mayorista
# 168037        Fijo  22.740396 -102.503876    2010-07      Mayorista
# 168038        Fijo  22.754184 -102.575988    2020-04      Mayorista
# 168039        Fijo  23.200119 -102.851135    2019-11      Mayorista
#
# [168040 rows x 43 columns]

# %% [markdown]
# Vamos a convertir los datos a geopandas ya que la información cuenta con latitudes y longitudes. Intentemos correrlo con geopandas, sin embargo lo más probable es que no podamos poner el fondo del mapa de México, ya que se encuentran a diferentes escalas

# %% [markdown]
# ### Create a GeoDataFrame

# %%
#create GeoDataFrame
gdf_mayoristas = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitud, df.latitud))
gdf_mayoristas.head()
# Out:
#         id                          clee  \
# 0  7702819  01001434225001101000000000S1
# 1  6282298  01005431110000031001004190S9
# 2  6281310  01005431191000017000002859S8
# 3  6281199  01001431191000106000002859S8
# 4  6281969  01001431110000121001004190S7
#
#                                   nom_estab                  raz_social  \
# 0      2 CONEXION DE SERVICIOS INFORMATICOS                         NaN
# 1  2227 ORGANIZACIÓN SAHUAYO AGUASCALIENTES  IMPULSORA SAHUAYO SA DE CV
# 2                          2251 AGUAS NORTE              BIMBO SA DE CV
# 3                            2252 AGUAS SUR              BIMBO SA DE CV
# 4                       2273 AGUASCALIENTES  IMPULSORA SAHUAYO SA DE CV
#
#    codigo_act                                         nombre_act  \
# 0      434225  Comercio al por mayor de equipo y material elé...
# 1      431110                 Comercio al por mayor de abarrotes
# 2      431191            Comercio al por mayor de pan y pasteles
# 3      431191            Comercio al por mayor de pan y pasteles
# 4      431110                 Comercio al por mayor de abarrotes
#
#               per_ocu  tipo_vial            nom_vial          tipo_v_e_1  ...  \
# 0      0 a 5 personas      CALLE           5 DE MAYO               CALLE  ...
# 1  101 a 250 personas   CIRCUITO  AGUASCALIENTES SUR            CIRCUITO  ...
# 2  251 y más personas  CARRETERA        PANAMERICANA  OTRO (ESPECIFIQUE)  ...
# 3  101 a 250 personas  CARRETERA    PANAMERICANA SUR               CALLE  ...
# 4  101 a 250 personas      CALLE                SOYA             AVENIDA  ...
#
#   manzana telefono               correoelec                 www tipoUniEco  \
# 0      14      NaN  SERVICIOS@2CONEXION.COM   WWW.2CONEXION.COM       Fijo
# 1       3      NaN                      NaN  WWW.SAHUAYO.COM.MX       Fijo
# 2     800      NaN                      NaN    WWW.BIMBO.COM.MX       Fijo
# 3      25      NaN                      NaN    WWW.BIMBO.COM.MX       Fijo
# 4      16      NaN                      NaN  WWW.SAHUAYO.COM.MX       Fijo
#
#      latitud    longitud fecha_alta Clasificación                     geometry
# 0  21.882623 -102.297289    2019-11     Mayorista  POINT (-102.29729 21.88262)
# 1  21.963603 -102.279136    2010-07     Mayorista  POINT (-102.27914 21.96360)
# 2  21.954421 -102.291284    2010-07     Mayorista  POINT (-102.29128 21.95442)
# 3  21.840966 -102.280381    2010-07     Mayorista  POINT (-102.28038 21.84097)
# 4  21.910507 -102.296908    2010-07     Mayorista  POINT (-102.29691 21.91051)
#
# [5 rows x 44 columns]

# %%
gdf_mayoristas.dtypes
# Out:
# id               int64
# clee            object
# nom_estab       object
# raz_social      object
# codigo_act       int64
# nombre_act      object
# per_ocu         object
# tipo_vial       object
# nom_vial        object
# tipo_v_e_1      object
# nom_v_e_1       object
# tipo_v_e_2      object
# nom_v_e_2       object
# tipo_v_e_3      object
# nom_v_e_3       object
# numero_ext     float64
# letra_ext       object
# edificio        object
# edificio_e      object
# numero_int     float64
# letra_int       object
# tipo_asent      object
# nomb_asent      object
# tipoCenCom      object
# nom_CenCom      object
# num_local       object
# cod_postal     float64
# cve_ent          int64
# entidad         object
# cve_mun          int64
# municipio       object
# cve_loc          int64
# localidad       object
# ageb            object
# manzana          int64
# telefono        object
# correoelec      object
# www             object
# tipoUniEco      object
# latitud        float64
# longitud       float64
# fecha_alta      object
# geometry      geometry
# dtype: object

# %%
gdf_mayoristas.plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1)

gdf_mayoristas.plot(column='per_ocu', ax=ax, legend=True, markersize=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #inegi:
# #el marco geoestadístico
# #https://www.inegi.org.mx/temas/mg/
#
# ![marco-geoestadistico.jpeg](C:\Users\User\Maestria\Tesis\marco-geoestadistico.jpeg)
#
# Bájate el primero
#
# ![marco-geoestadistico-2.jpeg](C:\Users\User\Maestria\Tesis\marco-geoestadistico-2.jpeg)
#
# Es un poco pesado pero ahí va a venir todos los shapefiles que podrías a necesitar de méxico
#
# Ya una vez que los descargues, nomás pregúntale a nuestro compa chatgpt cómo poner un shapefile
#
# Lo que tienes que hacer es es primero cargar los shapes de los estados y luego pones los puntos del mapa que me mostraste. Porque en todo el análisis geoespacial funciona con capas (como en fotoshop). Entonces, la primer capa es como "el fondo" y ahí van a venir las figuras de los estados y ya la segunda capa va a ser el "contenido", o sea las ubicaciones de los negocios abarroteros

# %%
#Vamos a juntarlo con por menor
df_menor = pd.read_csv('denue_inegi_46111_menor.csv', encoding='ISO-8859-1')
df_menor
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8020\363044225.py:2: DtypeWarning: Columns (35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_menor = pd.read_csv('denue_inegi_46111_menor.csv', encoding='ISO-8859-1')
#              id                          clee  \
# 0       7238693  01001461110053361000000000U8
# 1         29758  01001461110049131000000000U2
# 2         47438  01007713120000321010000000U8
# 3           929  01003461110002141001000000U2
# 4       7407280  01004461110000581000000000U9
# ...         ...                           ...
# 604386  9286131  32056461110013121000000000U2
# 604387  4638469  32034461110002551000000000U0
# 604388  4618939  32007461110001231000000000U6
# 604389  4638927  32023461110000921000000000U0
# 604390  4613882  32036811119000011010000000U0
#
#                               nom_estab                  raz_social  \
# 0                   ABARR0TES DON PEDRO                         NaN
# 1                   ABARR0TES EL SAIDER                         NaN
# 2                     ABARR0TES PUENTES                         NaN
# 3                            ABARROTERA                         NaN
# 4                 ABARROTERA DEL CENTRO                         NaN
# ...                                 ...                         ...
# 604386  VENTA DE PRODUCTOS VARIOS FRIDA  VENTA DE PRODECTOS VARIOS
# 604387     VENTA DE REFRESCO Y FRITURAS                         NaN
# 604388                         VERONICA                         NaN
# 604389       VERÓNICA PINEDA PLASCENCIA          ABARROTES MARYFER
# 604390        VIDRIOS Y MARCOS EL POLLO                         NaN
#
#         codigo_act                                         nombre_act  \
# 0           461110  Comercio al por menor en tiendas de abarrotes,...
# 1           461110  Comercio al por menor en tiendas de abarrotes,...
# 2           461110  Comercio al por menor en tiendas de abarrotes,...
# 3           461110  Comercio al por menor en tiendas de abarrotes,...
# 4           461110  Comercio al por menor en tiendas de abarrotes,...
# ...            ...                                                ...
# 604386      461110  Comercio al por menor en tiendas de abarrotes,...
# 604387      461110  Comercio al por menor en tiendas de abarrotes,...
# 604388      461110  Comercio al por menor en tiendas de abarrotes,...
# 604389      461110  Comercio al por menor en tiendas de abarrotes,...
# 604390      461110  Comercio al por menor en tiendas de abarrotes,...
#
#                 per_ocu  tipo_vial                   nom_vial tipo_v_e_1  ...  \
# 0        0 a 5 personas    AVENIDA                  POLIDUCTO      CALLE  ...
# 1        0 a 5 personas      CALLE        PASEO DE LA BIZNAGA    AVENIDA  ...
# 2        0 a 5 personas      CALLE         PLAZA GUEL JIMENEZ      CALLE  ...
# 3       6 a 10 personas  BOULEVARD  RODOLFO LANDEROS GALLEGOS      CALLE  ...
# 4        0 a 5 personas      CALLE        FRANCISCO I. MADERO    AVENIDA  ...
# ...                 ...        ...                        ...        ...  ...
# 604386   0 a 5 personas      CALLE                    NINGUNO      CALLE  ...
# 604387   0 a 5 personas      CALLE          LEOCADIO GONZALEZ    PRIVADA  ...
# 604388   0 a 5 personas      CALLE                   PROGRESO      CALLE  ...
# 604389   0 a 5 personas      CALLE    GENERAL ENRIQUE ESTRADA      CALLE  ...
# 604390   0 a 5 personas    AVENIDA          ESTEBAN CASTORENA    PRIVADA  ...
#
#                   localidad  ageb manzana      telefono correoelec  www  \
# 0            Aguascalientes  3238      16  4493296002.0        NaN  NaN
# 1            Aguascalientes  3613      25           NaN        NaN  NaN
# 2           Pablo Escaleras  0190       6           NaN        NaN  NaN
# 3                  Calvillo  0168      29  4959561441.0        NaN  NaN
# 4                     Cosío  0108       9           NaN        NaN  NaN
# ...                     ...   ...     ...           ...        ...  ...
# 604386            Zacatecas  0364      12           NaN        NaN  NaN
# 604387  Nochistlán de Mejía  0348      16           NaN        NaN  NaN
# 604388   Concepción del Oro  0533      34           NaN        NaN  NaN
# 604389            Juchipila  0132       1           NaN        NaN  NaN
# 604390          Ojocaliente  0041      32  4581018310.0        NaN  NaN
#
#        tipoUniEco    latitud    longitud  fecha_alta
# 0            Fijo  21.902728 -102.247834     2019-11
# 1            Fijo  21.868223 -102.232901     2014-12
# 2            Fijo  22.248455 -102.333434     2014-12
# 3            Fijo  21.847281 -102.704958     2010-07
# 4            Fijo  22.366288 -102.297583     2019-11
# ...           ...        ...         ...         ...
# 604386       Fijo  22.763928 -102.545492     2020-11
# 604387       Fijo  21.369744 -102.847340     2014-12
# 604388       Fijo  24.612876 -101.422822     2010-07
# 604389       Fijo  21.411978 -103.115767     2014-12
# 604390       Fijo  22.573627 -102.257767     2010-07
#
# [604391 rows x 42 columns]

# %%
#Agregamos la columna para minoristas
Minor = []
for i in range(len(df_menor)):
    Minorista = 'Menudeo'
    Minor.append(Minorista)

df_menor['Clasificación'] = Minor
df_menor
# Out:
#              id                          clee  \
# 0       7238693  01001461110053361000000000U8
# 1         29758  01001461110049131000000000U2
# 2         47438  01007713120000321010000000U8
# 3           929  01003461110002141001000000U2
# 4       7407280  01004461110000581000000000U9
# ...         ...                           ...
# 604386  9286131  32056461110013121000000000U2
# 604387  4638469  32034461110002551000000000U0
# 604388  4618939  32007461110001231000000000U6
# 604389  4638927  32023461110000921000000000U0
# 604390  4613882  32036811119000011010000000U0
#
#                               nom_estab                  raz_social  \
# 0                   ABARR0TES DON PEDRO                         NaN
# 1                   ABARR0TES EL SAIDER                         NaN
# 2                     ABARR0TES PUENTES                         NaN
# 3                            ABARROTERA                         NaN
# 4                 ABARROTERA DEL CENTRO                         NaN
# ...                                 ...                         ...
# 604386  VENTA DE PRODUCTOS VARIOS FRIDA  VENTA DE PRODECTOS VARIOS
# 604387     VENTA DE REFRESCO Y FRITURAS                         NaN
# 604388                         VERONICA                         NaN
# 604389       VERÓNICA PINEDA PLASCENCIA          ABARROTES MARYFER
# 604390        VIDRIOS Y MARCOS EL POLLO                         NaN
#
#         codigo_act                                         nombre_act  \
# 0           461110  Comercio al por menor en tiendas de abarrotes,...
# 1           461110  Comercio al por menor en tiendas de abarrotes,...
# 2           461110  Comercio al por menor en tiendas de abarrotes,...
# 3           461110  Comercio al por menor en tiendas de abarrotes,...
# 4           461110  Comercio al por menor en tiendas de abarrotes,...
# ...            ...                                                ...
# 604386      461110  Comercio al por menor en tiendas de abarrotes,...
# 604387      461110  Comercio al por menor en tiendas de abarrotes,...
# 604388      461110  Comercio al por menor en tiendas de abarrotes,...
# 604389      461110  Comercio al por menor en tiendas de abarrotes,...
# 604390      461110  Comercio al por menor en tiendas de abarrotes,...
#
#                 per_ocu  tipo_vial                   nom_vial tipo_v_e_1  ...  \
# 0        0 a 5 personas    AVENIDA                  POLIDUCTO      CALLE  ...
# 1        0 a 5 personas      CALLE        PASEO DE LA BIZNAGA    AVENIDA  ...
# 2        0 a 5 personas      CALLE         PLAZA GUEL JIMENEZ      CALLE  ...
# 3       6 a 10 personas  BOULEVARD  RODOLFO LANDEROS GALLEGOS      CALLE  ...
# 4        0 a 5 personas      CALLE        FRANCISCO I. MADERO    AVENIDA  ...
# ...                 ...        ...                        ...        ...  ...
# 604386   0 a 5 personas      CALLE                    NINGUNO      CALLE  ...
# 604387   0 a 5 personas      CALLE          LEOCADIO GONZALEZ    PRIVADA  ...
# 604388   0 a 5 personas      CALLE                   PROGRESO      CALLE  ...
# 604389   0 a 5 personas      CALLE    GENERAL ENRIQUE ESTRADA      CALLE  ...
# 604390   0 a 5 personas    AVENIDA          ESTEBAN CASTORENA    PRIVADA  ...
#
#         ageb manzana      telefono correoelec  www  tipoUniEco    latitud  \
# 0       3238      16  4493296002.0        NaN  NaN        Fijo  21.902728
# 1       3613      25           NaN        NaN  NaN        Fijo  21.868223
# 2       0190       6           NaN        NaN  NaN        Fijo  22.248455
# 3       0168      29  4959561441.0        NaN  NaN        Fijo  21.847281
# 4       0108       9           NaN        NaN  NaN        Fijo  22.366288
# ...      ...     ...           ...        ...  ...         ...        ...
# 604386  0364      12           NaN        NaN  NaN        Fijo  22.763928
# 604387  0348      16           NaN        NaN  NaN        Fijo  21.369744
# 604388  0533      34           NaN        NaN  NaN        Fijo  24.612876
# 604389  0132       1           NaN        NaN  NaN        Fijo  21.411978
# 604390  0041      32  4581018310.0        NaN  NaN        Fijo  22.573627
#
#           longitud fecha_alta  Clasificación
# 0      -102.247834    2019-11        Menudeo
# 1      -102.232901    2014-12        Menudeo
# 2      -102.333434    2014-12        Menudeo
# 3      -102.704958    2010-07        Menudeo
# 4      -102.297583    2019-11        Menudeo
# ...            ...        ...            ...
# 604386 -102.545492    2020-11        Menudeo
# 604387 -102.847340    2014-12        Menudeo
# 604388 -101.422822    2010-07        Menudeo
# 604389 -103.115767    2014-12        Menudeo
# 604390 -102.257767    2010-07        Menudeo
#
# [604391 rows x 43 columns]

# %%
#create GeoDataFrame
gdf_minoristas = gpd.GeoDataFrame(df_menor, geometry=gpd.points_from_xy(df_menor.longitud, df_menor.latitud))
gdf_minoristas.head()
# Out:
#         id                          clee              nom_estab raz_social  \
# 0  7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO        NaN
# 1    29758  01001461110049131000000000U2    ABARR0TES EL SAIDER        NaN
# 2    47438  01007713120000321010000000U8      ABARR0TES PUENTES        NaN
# 3      929  01003461110002141001000000U2             ABARROTERA        NaN
# 4  7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO        NaN
#
#    codigo_act                                         nombre_act  \
# 0      461110  Comercio al por menor en tiendas de abarrotes,...
# 1      461110  Comercio al por menor en tiendas de abarrotes,...
# 2      461110  Comercio al por menor en tiendas de abarrotes,...
# 3      461110  Comercio al por menor en tiendas de abarrotes,...
# 4      461110  Comercio al por menor en tiendas de abarrotes,...
#
#            per_ocu  tipo_vial                   nom_vial tipo_v_e_1  ...  \
# 0   0 a 5 personas    AVENIDA                  POLIDUCTO      CALLE  ...
# 1   0 a 5 personas      CALLE        PASEO DE LA BIZNAGA    AVENIDA  ...
# 2   0 a 5 personas      CALLE         PLAZA GUEL JIMENEZ      CALLE  ...
# 3  6 a 10 personas  BOULEVARD  RODOLFO LANDEROS GALLEGOS      CALLE  ...
# 4   0 a 5 personas      CALLE        FRANCISCO I. MADERO    AVENIDA  ...
#
#   manzana      telefono correoelec  www tipoUniEco    latitud    longitud  \
# 0      16  4493296002.0        NaN  NaN       Fijo  21.902728 -102.247834
# 1      25           NaN        NaN  NaN       Fijo  21.868223 -102.232901
# 2       6           NaN        NaN  NaN       Fijo  22.248455 -102.333434
# 3      29  4959561441.0        NaN  NaN       Fijo  21.847281 -102.704958
# 4       9           NaN        NaN  NaN       Fijo  22.366288 -102.297583
#
#   fecha_alta Clasificación                     geometry
# 0    2019-11       Menudeo  POINT (-102.24783 21.90273)
# 1    2014-12       Menudeo  POINT (-102.23290 21.86822)
# 2    2014-12       Menudeo  POINT (-102.33343 22.24845)
# 3    2010-07       Menudeo  POINT (-102.70496 21.84728)
# 4    2019-11       Menudeo  POINT (-102.29758 22.36629)
#
# [5 rows x 44 columns]

# %%
gdf_minoristas.dtypes
# Out:
# id                  int64
# clee               object
# nom_estab          object
# raz_social         object
# codigo_act          int64
# nombre_act         object
# per_ocu            object
# tipo_vial          object
# nom_vial           object
# tipo_v_e_1         object
# nom_v_e_1          object
# tipo_v_e_2         object
# nom_v_e_2          object
# tipo_v_e_3         object
# nom_v_e_3          object
# numero_ext        float64
# letra_ext          object
# edificio           object
# edificio_e         object
# numero_int        float64
# letra_int          object
# tipo_asent         object
# nomb_asent         object
# tipoCenCom         object
# nom_CenCom         object
# num_local          object
# cod_postal        float64
# cve_ent             int64
# entidad            object
# cve_mun             int64
# municipio          object
# cve_loc             int64
# localidad          object
# ageb               object
# manzana             int64
# telefono           object
# correoelec         object
# www                object
# tipoUniEco         object
# latitud           float64
# longitud          float64
# fecha_alta         object
# Clasificación      object
# geometry         geometry
# dtype: object

# %%
gdf_minoristas.plot()
# Out:
# <AxesSubplot:>
